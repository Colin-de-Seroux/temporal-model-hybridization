# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

df = pd.read_csv("dataset/dataset.csv")
model_name = "hello_1"
group = df[df["ModelName"] == model_name]

action_type_onehot = {
    'timer': [1, 0, 0],
    'pub': [0, 1, 0],
    'sub': [0, 0, 1],
}

unique_topics = df["Topic"].dropna().unique()
topic_to_id = {topic: i for i, topic in enumerate(unique_topics)}

G = nx.DiGraph()

for idx, row in group.iterrows():
    node_id = f'{row["NodeName"]}-{row["ActionType"]}'

    one_hot = action_type_onehot[row["ActionType"]]

    topic_id = topic_to_id.get(row["Topic"], -1)

    period = row["Value"] if row["ActionType"] == "timer" else 0.0

    feature_vector = one_hot + [topic_id, period, row["ActionOrder"]]

    G.add_node(
        node_id,
        label=node_id,
        features=feature_vector,
        target=row["ExecutionTime"],
        node=row["NodeName"],
        topic=row["Topic"]
    )

# timer → pub (même node)
timers = group[group["ActionType"] == "timer"]
publishers = group[group["ActionType"] == "pub"]
subscribers = group[group["ActionType"] == "sub"]

for _, timer in timers.iterrows():
    for _, pub in publishers.iterrows():
        if timer["NodeName"] == pub["NodeName"]:
            src = f'{timer["NodeName"]}-timer'
            dst = f'{pub["NodeName"]}-pub'
            G.add_edge(src, dst, label="timer→pub")

# pub → sub (même topic)
for _, pub in publishers.iterrows():
    for _, sub in subscribers.iterrows():
        if pub["Topic"] == sub["Topic"]:
            src = f'{pub["NodeName"]}-pub'
            dst = f'{sub["NodeName"]}-sub'
            G.add_edge(src, dst, label="pub→sub")


# for _, pub1 in publishers.iterrows():
#     for _, pub2 in publishers.iterrows():
#         if pub1["NodeName"] == pub2["NodeName"] and pub1["ActionOrder"] < pub2["ActionOrder"]:
#             G.add_edge(f'{pub1["NodeName"]}-pub', f'{pub2["NodeName"]}-pub', label="pub→pub")

for node_id, data in G.nodes(data=True):
    print(f"{node_id} : features={data['features']} | target={data['target']}")

plt.figure(figsize=(8, 6))
pos = nx.spring_layout(G, seed=42)
labels = nx.get_node_attributes(G, 'label')
node_labels = {
    n: f"{d['label']}\nfeatures={d['features']}\ntarget={d['target']:.4f}"
    for n, d in G.nodes(data=True)
}
nx.draw(G, pos, with_labels=True, labels=node_labels, node_color='lightblue', node_size=1500, font_size=10)
edge_labels = nx.get_edge_attributes(G, 'label')

nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels)
plt.title(f"Graphe du modele '{model_name}'")
plt.show()
# Out:
# Subscriber_2-sub : features=[0, 0, 1, 0, 0.0, 0] | target=0.00111
# Publisher_3-pub : features=[0, 1, 0, 0, 0.0, 1] | target=0.0
# Publisher_3-timer : features=[1, 0, 0, -1, 1000.0, 0] | target=0.99991

# %%
import pandas as pd
import networkx as nx
import numpy as np
from torch_geometric_temporal.signal import StaticGraphTemporalSignal,DynamicGraphTemporalSignal
from torch_geometric_temporal.signal import temporal_signal_split


df = pd.read_csv("dataset/dataset.csv")
##############Création du graph############################################################################
action_type_onehot = {
    'timer': [1, 0, 0],
    'pub': [0, 1, 0],
    'sub': [0, 0, 1],
}

unique_topics = df["Topic"].dropna().unique()
topic_to_id = {topic: i for i, topic in enumerate(unique_topics)}

graphs = {}

for model_name in df["ModelName"].unique():
    group = df[df["ModelName"] == model_name]

    G = nx.DiGraph()
    node_features = []
    targets = []
    node_index_map = {}

    for idx, row in group.iterrows():
        node_id = f'{row["NodeName"]}-{row["ActionType"]}'
        if node_id not in node_index_map:
            node_index = len(node_index_map)
            node_index_map[node_id] = node_index

            one_hot = action_type_onehot[row["ActionType"]]
            topic_id = topic_to_id.get(row["Topic"], -1)
            period = row["Value"] if row["ActionType"] == "timer" else 0.0
            feature_vector = one_hot + [topic_id, period, row["ActionOrder"]]
            if row["ActionType"] == "timer" and row["Value"] != 0:
                target = (row["ExecutionTime"] - row["Value"]) / row["Value"]  
            else:
                target = row["ExecutionTime"]  

            G.add_node(node_id, features=feature_vector, target=target)
            node_features.append(feature_vector)
            targets.append(target)

    # timer → pub (same node)
    timers = group[group["ActionType"] == "timer"]
    publishers = group[group["ActionType"] == "pub"]
    subscribers = group[group["ActionType"] == "sub"]

    for _, timer in timers.iterrows():
        for _, pub in publishers.iterrows():
            if timer["NodeName"] == pub["NodeName"]:
                src = f'{timer["NodeName"]}-timer'
                dst = f'{pub["NodeName"]}-pub'
                G.add_edge(src, dst)
                G[src][dst]['weight'] = abs(G.nodes[dst]['target'] - G.nodes[src]['target'])

    # pub → sub (same topic)
    for _, pub in publishers.iterrows():
        for _, sub in subscribers.iterrows():
            if pub["Topic"] == sub["Topic"]:
                src = f'{pub["NodeName"]}-pub'
                dst = f'{sub["NodeName"]}-sub'
                G.add_edge(src, dst)
                G[src][dst]['weight'] = abs(G.nodes[dst]['target'] - G.nodes[src]['target'])

    edge_index = np.array([
        [node_index_map[src], node_index_map[dst]]
        for src, dst in G.edges()
    ]).T 

    edge_weight1 = np.array([
        G.nodes[src]['target']
        for src, dst in G.edges()
    ], dtype=np.float32)


    features = np.array(node_features, dtype=np.float32)
    targets = np.array(targets, dtype=np.float32)

    target_sequence = [targets for _ in range(1)]  

    dataset = DynamicGraphTemporalSignal(
        edge_indices=[edge_index],
        edge_weights=[edge_weight1],
        features=[features],  
        targets=target_sequence
    )
    print(dataset)
    graphs[model_name] = dataset
    print(f"✓ Graphe pour '{model_name}' créé avec {features.shape[0]} nœuds et {edge_index.shape[1]} arêtes.")

    #########################UTILS############################################################################################################

def print_graph_info(graphs):
    for model_name, dataset in graphs.items():
        print(f"Modèle: {model_name}")
        print(f"  Nombre de nœuds: {dataset.features[0].shape[0]}")
        print(f"  Nombre d'arêtes: {dataset.edge_index.shape[1]}")
        print(f"  Dimensions des caractéristiques: {dataset.features[0].shape[1]}")
        print(f"  Dimensions des cibles: {dataset.targets[0].shape[1]}")
        print()

def print_features(graphs):
    for model_name, dataset in graphs.items():
        print(f"Modèle: {model_name}")
        for i, features in enumerate(dataset.features):
            print(f"  Snapshot {i+1}:")
            for j, feature in enumerate(features):
                target = dataset.targets[i][j]
                print(f"    Nœud {j}: features={feature}, target={target}")
        print()

def visualize_graph(G, model_name):
    import matplotlib.pyplot as plt

    pos = nx.spring_layout(G, seed=42)
    node_labels = {
        n: f"{n}\nfeatures={d['features']}\ntarget={d['target']}"
        for n, d in G.nodes(data=True)
    }

    edge_labels = {
        (u, v): f"{d['weight']}"
        for u, v, d in G.edges(data=True)
    }

    plt.figure(figsize=(8, 6))
    nx.draw(G, pos, with_labels=True, labels=node_labels, node_color='lightblue', node_size=1500, font_size=9)
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red')
    plt.title(f"Graphe du modele '{model_name}' (edge weight = target source)")
    plt.show()


# visualize_graph(G, 'hello_10')
# print_features(graphs)


##########################################IA##########################################################
try:
    from tqdm import tqdm
except ImportError:
    def tqdm(iterable):
        return iterable

import torch
import torch.nn.functional as F
from torch_geometric_temporal.nn.recurrent import AGCRN

from torch_geometric_temporal.signal import temporal_signal_split


class RecurrentGCN(torch.nn.Module):
    def __init__(self, node_features):
        super(RecurrentGCN, self).__init__()
        self.recurrent = AGCRN(number_of_nodes = 20,
                              in_channels = node_features,
                              out_channels = 2,
                              K = 2,
                              embedding_dimensions = 4)
        self.linear = torch.nn.Linear(2, 1)

    def forward(self, x, e, h):
        h_0 = self.recurrent(x, e, h)
        y = F.relu(h_0)
        y = self.linear(y)
        return y, h_0
# Out:
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68AB8860>
# ✓ Graphe pour 'hello_0' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68ABB1A0>
# ✓ Graphe pour 'hello_1' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA686FC1A0>
# ✓ Graphe pour 'hello_2' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68A6AC60>
# ✓ Graphe pour 'hello_3' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA611D42C0>
# ✓ Graphe pour 'hello_4' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C43E390>
# ✓ Graphe pour 'hello_5' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA61A82180>
# ✓ Graphe pour 'hello_6' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA61A82480>
# ✓ Graphe pour 'hello_7' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C647590>
# ✓ Graphe pour 'hello_8' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6478F0>
# ✓ Graphe pour 'hello_9' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C687F50>
# ✓ Graphe pour 'hello_10' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C684E30>
# ✓ Graphe pour 'hello_11' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C82E900>
# ✓ Graphe pour 'hello_12' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DF830>
# ✓ Graphe pour 'hello_13' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DF2C0>
# ✓ Graphe pour 'hello_14' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DEAE0>
# ✓ Graphe pour 'hello_15' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DD370>
# ✓ Graphe pour 'hello_16' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DEA50>
# ✓ Graphe pour 'hello_17' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A83B0>
# ✓ Graphe pour 'hello_18' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A9490>
# ✓ Graphe pour 'hello_19' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AAED0>
# ✓ Graphe pour 'hello_20' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C685D00>
# ✓ Graphe pour 'hello_21' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C685B50>
# ✓ Graphe pour 'hello_22' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68905640>
# ✓ Graphe pour 'hello_23' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AA900>
# ✓ Graphe pour 'hello_24' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AB440>
# ✓ Graphe pour 'hello_25' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A88C0>
# ✓ Graphe pour 'hello_26' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AB2F0>
# ✓ Graphe pour 'hello_27' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68B6F4A0>
# ✓ Graphe pour 'hello_28' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA619EA5A0>
# ✓ Graphe pour 'hello_29' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C645790>
# ✓ Graphe pour 'hello_30' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68AC6FF0>
# ✓ Graphe pour 'hello_31' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68A73290>
# ✓ Graphe pour 'hello_32' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68ABB7A0>
# ✓ Graphe pour 'hello_33' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C43D010>
# ✓ Graphe pour 'hello_34' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A8E90>
# ✓ Graphe pour 'hello_35' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68A698B0>
# ✓ Graphe pour 'hello_36' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68316AE0>
# ✓ Graphe pour 'hello_37' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C646180>
# ✓ Graphe pour 'hello_38' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DD9A0>
# ✓ Graphe pour 'hello_39' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68A73710>
# ✓ Graphe pour 'hello_40' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68A716D0>
# ✓ Graphe pour 'hello_41' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C53C110>
# ✓ Graphe pour 'hello_42' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA61A82540>
# ✓ Graphe pour 'hello_43' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA0A8A5700>
# ✓ Graphe pour 'hello_44' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C82DBB0>
# ✓ Graphe pour 'hello_45' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA689048C0>
# ✓ Graphe pour 'hello_46' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68905220>
# ✓ Graphe pour 'hello_47' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68905580>
# ✓ Graphe pour 'hello_48' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DFEF0>
# ✓ Graphe pour 'hello_49' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DEF90>
# ✓ Graphe pour 'hello_50' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DECC0>
# ✓ Graphe pour 'hello_51' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DE900>
# ✓ Graphe pour 'hello_52' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4ABCB0>
# ✓ Graphe pour 'hello_53' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A8410>
# ✓ Graphe pour 'hello_54' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A8980>
# ✓ Graphe pour 'hello_55' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AA8A0>
# ✓ Graphe pour 'hello_56' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A8C80>
# ✓ Graphe pour 'hello_57' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AA030>
# ✓ Graphe pour 'hello_58' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6748F0>
# ✓ Graphe pour 'hello_59' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C677F80>
# ✓ Graphe pour 'hello_60' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C677050>
# ✓ Graphe pour 'hello_61' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C676780>
# ✓ Graphe pour 'hello_62' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6772F0>
# ✓ Graphe pour 'hello_63' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C677FB0>
# ✓ Graphe pour 'hello_64' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C675AC0>
# ✓ Graphe pour 'hello_65' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C675580>
# ✓ Graphe pour 'hello_66' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AB6B0>
# ✓ Graphe pour 'hello_67' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A9AF0>
# ✓ Graphe pour 'hello_68' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DD130>
# ✓ Graphe pour 'hello_69' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA689052E0>
# ✓ Graphe pour 'hello_70' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C752810>
# ✓ Graphe pour 'hello_71' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DDDF0>
# ✓ Graphe pour 'hello_72' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA5F9CE570>
# ✓ Graphe pour 'hello_73' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68AC7260>
# ✓ Graphe pour 'hello_74' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68ABABA0>
# ✓ Graphe pour 'hello_75' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68B4B5F0>
# ✓ Graphe pour 'hello_76' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C82D970>
# ✓ Graphe pour 'hello_77' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68A6B2C0>
# ✓ Graphe pour 'hello_78' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA5FCDADE0>
# ✓ Graphe pour 'hello_79' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA61033EF0>
# ✓ Graphe pour 'hello_80' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A80B0>
# ✓ Graphe pour 'hello_81' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C753110>
# ✓ Graphe pour 'hello_82' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA5FF882F0>
# ✓ Graphe pour 'hello_83' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA61A82390>
# ✓ Graphe pour 'hello_84' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DC320>
# ✓ Graphe pour 'hello_85' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68ABA360>
# ✓ Graphe pour 'hello_86' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA5F8C6510>
# ✓ Graphe pour 'hello_87' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C53EF30>
# ✓ Graphe pour 'hello_88' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AB110>
# ✓ Graphe pour 'hello_89' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DF350>
# ✓ Graphe pour 'hello_90' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A81D0>
# ✓ Graphe pour 'hello_91' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DD6A0>
# ✓ Graphe pour 'hello_92' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A8CE0>
# ✓ Graphe pour 'hello_93' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AB8F0>
# ✓ Graphe pour 'hello_94' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AA840>
# ✓ Graphe pour 'hello_95' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C677C20>
# ✓ Graphe pour 'hello_96' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6753D0>
# ✓ Graphe pour 'hello_97' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C676DB0>
# ✓ Graphe pour 'hello_98' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C675EE0>
# ✓ Graphe pour 'hello_99' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C674590>
# ✓ Graphe pour 'hello_100' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C674BC0>
# ✓ Graphe pour 'hello_101' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C70B0>
# ✓ Graphe pour 'hello_102' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C677260>
# ✓ Graphe pour 'hello_103' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AB0B0>
# ✓ Graphe pour 'hello_104' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6771D0>
# ✓ Graphe pour 'hello_105' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C674230>
# ✓ Graphe pour 'hello_106' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C676060>
# ✓ Graphe pour 'hello_107' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C676990>
# ✓ Graphe pour 'hello_108' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA61A831A0>
# ✓ Graphe pour 'hello_109' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C675100>
# ✓ Graphe pour 'hello_110' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA5FD318B0>
# ✓ Graphe pour 'hello_111' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DF650>
# ✓ Graphe pour 'hello_112' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DED50>
# ✓ Graphe pour 'hello_113' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C686420>
# ✓ Graphe pour 'hello_114' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DD2E0>
# ✓ Graphe pour 'hello_115' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C53F8F0>
# ✓ Graphe pour 'hello_116' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C53DEB0>
# ✓ Graphe pour 'hello_117' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A93D0>
# ✓ Graphe pour 'hello_118' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4ABAA0>
# ✓ Graphe pour 'hello_119' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5C70>
# ✓ Graphe pour 'hello_120' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5E50>
# ✓ Graphe pour 'hello_121' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C7620>
# ✓ Graphe pour 'hello_122' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C65A0>
# ✓ Graphe pour 'hello_123' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C43C920>
# ✓ Graphe pour 'hello_124' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C43E9F0>
# ✓ Graphe pour 'hello_125' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA689068A0>
# ✓ Graphe pour 'hello_126' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA689058B0>
# ✓ Graphe pour 'hello_127' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C644D70>
# ✓ Graphe pour 'hello_128' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C647920>
# ✓ Graphe pour 'hello_129' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C82CAD0>
# ✓ Graphe pour 'hello_130' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DE840>
# ✓ Graphe pour 'hello_131' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DCF50>
# ✓ Graphe pour 'hello_132' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DE4B0>
# ✓ Graphe pour 'hello_133' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C675A60>
# ✓ Graphe pour 'hello_134' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C674710>
# ✓ Graphe pour 'hello_135' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C677D70>
# ✓ Graphe pour 'hello_136' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C676600>
# ✓ Graphe pour 'hello_137' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AB2C0>
# ✓ Graphe pour 'hello_138' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A8A10>
# ✓ Graphe pour 'hello_139' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A9340>
# ✓ Graphe pour 'hello_140' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A85F0>
# ✓ Graphe pour 'hello_141' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4ABDD0>
# ✓ Graphe pour 'hello_142' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6FC0>
# ✓ Graphe pour 'hello_143' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C63F0>
# ✓ Graphe pour 'hello_144' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A8710>
# ✓ Graphe pour 'hello_145' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C647170>
# ✓ Graphe pour 'hello_146' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA0A8A4800>
# ✓ Graphe pour 'hello_147' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68AC7CB0>
# ✓ Graphe pour 'hello_148' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DECF0>
# ✓ Graphe pour 'hello_149' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DD5B0>
# ✓ Graphe pour 'hello_150' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68AB9430>
# ✓ Graphe pour 'hello_151' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AB140>
# ✓ Graphe pour 'hello_152' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AB230>
# ✓ Graphe pour 'hello_153' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4ABE00>
# ✓ Graphe pour 'hello_154' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C686060>
# ✓ Graphe pour 'hello_155' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AA450>
# ✓ Graphe pour 'hello_156' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C675760>
# ✓ Graphe pour 'hello_157' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6769C0>
# ✓ Graphe pour 'hello_158' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C675010>
# ✓ Graphe pour 'hello_159' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C674E00>
# ✓ Graphe pour 'hello_160' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C68D0>
# ✓ Graphe pour 'hello_161' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5DF0>
# ✓ Graphe pour 'hello_162' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6300>
# ✓ Graphe pour 'hello_163' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4F80>
# ✓ Graphe pour 'hello_164' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5AF0>
# ✓ Graphe pour 'hello_165' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68AB8E30>
# ✓ Graphe pour 'hello_166' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA684B8FE0>
# ✓ Graphe pour 'hello_167' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA0A8D9E20>
# ✓ Graphe pour 'hello_168' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA61A826C0>
# ✓ Graphe pour 'hello_169' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C82FAA0>
# ✓ Graphe pour 'hello_170' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DCC20>
# ✓ Graphe pour 'hello_171' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C674E60>
# ✓ Graphe pour 'hello_172' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DE5D0>
# ✓ Graphe pour 'hello_173' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DC500>
# ✓ Graphe pour 'hello_174' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C674F50>
# ✓ Graphe pour 'hello_175' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AA540>
# ✓ Graphe pour 'hello_176' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A8AA0>
# ✓ Graphe pour 'hello_177' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A92B0>
# ✓ Graphe pour 'hello_178' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AA000>
# ✓ Graphe pour 'hello_179' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5B80>
# ✓ Graphe pour 'hello_180' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4950>
# ✓ Graphe pour 'hello_181' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C56D0>
# ✓ Graphe pour 'hello_182' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C77D0>
# ✓ Graphe pour 'hello_183' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6C00>
# ✓ Graphe pour 'hello_184' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4290>
# ✓ Graphe pour 'hello_185' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4DD0>
# ✓ Graphe pour 'hello_186' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DDD00>
# ✓ Graphe pour 'hello_187' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C82D910>
# ✓ Graphe pour 'hello_188' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DE330>
# ✓ Graphe pour 'hello_189' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6470B0>
# ✓ Graphe pour 'hello_190' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DD850>
# ✓ Graphe pour 'hello_191' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A9280>
# ✓ Graphe pour 'hello_192' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DFF20>
# ✓ Graphe pour 'hello_193' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AB7A0>
# ✓ Graphe pour 'hello_194' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A85C0>
# ✓ Graphe pour 'hello_195' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C675520>
# ✓ Graphe pour 'hello_196' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6760C0>
# ✓ Graphe pour 'hello_197' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C676CF0>
# ✓ Graphe pour 'hello_198' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6743B0>
# ✓ Graphe pour 'hello_199' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5880>
# ✓ Graphe pour 'hello_200' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C74A0>
# ✓ Graphe pour 'hello_201' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6B40>
# ✓ Graphe pour 'hello_202' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6600>
# ✓ Graphe pour 'hello_203' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C45C0>
# ✓ Graphe pour 'hello_204' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6F30>
# ✓ Graphe pour 'hello_205' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C7DD0>
# ✓ Graphe pour 'hello_206' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C7BF0>
# ✓ Graphe pour 'hello_207' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C43D490>
# ✓ Graphe pour 'hello_208' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68A6B830>
# ✓ Graphe pour 'hello_209' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C644470>
# ✓ Graphe pour 'hello_210' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DE450>
# ✓ Graphe pour 'hello_211' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C644080>
# ✓ Graphe pour 'hello_212' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C675190>
# ✓ Graphe pour 'hello_213' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C677B00>
# ✓ Graphe pour 'hello_214' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A8D70>
# ✓ Graphe pour 'hello_215' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AA300>
# ✓ Graphe pour 'hello_216' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AB830>
# ✓ Graphe pour 'hello_217' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A8740>
# ✓ Graphe pour 'hello_218' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C47A0>
# ✓ Graphe pour 'hello_219' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5D30>
# ✓ Graphe pour 'hello_220' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4110>
# ✓ Graphe pour 'hello_221' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C58E0>
# ✓ Graphe pour 'hello_222' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C7D70>
# ✓ Graphe pour 'hello_223' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C79E0>
# ✓ Graphe pour 'hello_224' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5AC0>
# ✓ Graphe pour 'hello_225' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5280>
# ✓ Graphe pour 'hello_226' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C7A40>
# ✓ Graphe pour 'hello_227' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4500>
# ✓ Graphe pour 'hello_228' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C46B0>
# ✓ Graphe pour 'hello_229' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C68A0>
# ✓ Graphe pour 'hello_230' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4AA0>
# ✓ Graphe pour 'hello_231' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C7410>
# ✓ Graphe pour 'hello_232' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C46E0>
# ✓ Graphe pour 'hello_233' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C42F0>
# ✓ Graphe pour 'hello_234' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C7800>
# ✓ Graphe pour 'hello_235' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C52B0>
# ✓ Graphe pour 'hello_236' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4B90>
# ✓ Graphe pour 'hello_237' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A9670>
# ✓ Graphe pour 'hello_238' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA61A824B0>
# ✓ Graphe pour 'hello_239' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AACC0>
# ✓ Graphe pour 'hello_240' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA68A6B6B0>
# ✓ Graphe pour 'hello_241' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C53FF50>
# ✓ Graphe pour 'hello_242' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C686C60>
# ✓ Graphe pour 'hello_243' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4830>
# ✓ Graphe pour 'hello_244' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C676A20>
# ✓ Graphe pour 'hello_245' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5250>
# ✓ Graphe pour 'hello_246' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C7D10>
# ✓ Graphe pour 'hello_247' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C59D0>
# ✓ Graphe pour 'hello_248' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6762A0>
# ✓ Graphe pour 'hello_249' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6855E0>
# ✓ Graphe pour 'hello_250' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C53CE90>
# ✓ Graphe pour 'hello_251' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C644680>
# ✓ Graphe pour 'hello_252' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA619E9E50>
# ✓ Graphe pour 'hello_253' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AA4E0>
# ✓ Graphe pour 'hello_254' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A8110>
# ✓ Graphe pour 'hello_255' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C676900>
# ✓ Graphe pour 'hello_256' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4A9D30>
# ✓ Graphe pour 'hello_257' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5CD0>
# ✓ Graphe pour 'hello_258' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C53D0>
# ✓ Graphe pour 'hello_259' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5850>
# ✓ Graphe pour 'hello_260' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5D00>
# ✓ Graphe pour 'hello_261' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C7260>
# ✓ Graphe pour 'hello_262' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4E90>
# ✓ Graphe pour 'hello_263' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C7F50>
# ✓ Graphe pour 'hello_264' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6D50>
# ✓ Graphe pour 'hello_265' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6E40>
# ✓ Graphe pour 'hello_266' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5CA0>
# ✓ Graphe pour 'hello_267' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C64B0>
# ✓ Graphe pour 'hello_268' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6120>
# ✓ Graphe pour 'hello_269' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C783AA0>
# ✓ Graphe pour 'hello_270' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C7020>
# ...
# ✓ Graphe pour 'hello_386' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C782150>
# ✓ Graphe pour 'hello_387' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C7809E0>
# ✓ Graphe pour 'hello_388' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5340>
# ✓ Graphe pour 'hello_389' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6C90>
# ✓ Graphe pour 'hello_390' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C60C0>
# ✓ Graphe pour 'hello_391' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4230>
# ✓ Graphe pour 'hello_392' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5D60>
# ✓ Graphe pour 'hello_393' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4050>
# ✓ Graphe pour 'hello_394' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C7B30>
# ✓ Graphe pour 'hello_395' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4B30>
# ✓ Graphe pour 'hello_396' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4620>
# ✓ Graphe pour 'hello_397' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5BE0>
# ✓ Graphe pour 'hello_398' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C45F0>
# ✓ Graphe pour 'hello_399' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4C50>
# ✓ Graphe pour 'hello_400' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4AAFC0>
# ✓ Graphe pour 'hello_401' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C676210>
# ✓ Graphe pour 'hello_402' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6767B0>
# ✓ Graphe pour 'hello_403' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6DF1D0>
# ✓ Graphe pour 'hello_404' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6AB0>
# ✓ Graphe pour 'hello_405' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6210>
# ✓ Graphe pour 'hello_406' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C7EF0>
# ✓ Graphe pour 'hello_407' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C57C0>
# ✓ Graphe pour 'hello_408' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C48F0>
# ✓ Graphe pour 'hello_409' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C781FD0>
# ✓ Graphe pour 'hello_410' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C782FF0>
# ✓ Graphe pour 'hello_411' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C781E50>
# ✓ Graphe pour 'hello_412' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C780CB0>
# ✓ Graphe pour 'hello_413' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C7804D0>
# ✓ Graphe pour 'hello_414' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C7827E0>
# ✓ Graphe pour 'hello_415' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C782D80>
# ✓ Graphe pour 'hello_416' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C5247D0>
# ✓ Graphe pour 'hello_417' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C781220>
# ✓ Graphe pour 'hello_418' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C783020>
# ✓ Graphe pour 'hello_419' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C781CD0>
# ✓ Graphe pour 'hello_420' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6754C0>
# ✓ Graphe pour 'hello_421' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C674C20>
# ✓ Graphe pour 'hello_422' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C677890>
# ✓ Graphe pour 'hello_423' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C780D10>
# ✓ Graphe pour 'hello_424' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C781610>
# ✓ Graphe pour 'hello_425' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C782C60>
# ✓ Graphe pour 'hello_426' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6900>
# ✓ Graphe pour 'hello_427' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4AD0>
# ✓ Graphe pour 'hello_428' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C73E0>
# ✓ Graphe pour 'hello_429' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6840>
# ✓ Graphe pour 'hello_430' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C58B0>
# ✓ Graphe pour 'hello_431' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C43E0>
# ✓ Graphe pour 'hello_432' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6B70>
# ✓ Graphe pour 'hello_433' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6660>
# ✓ Graphe pour 'hello_434' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C527980>
# ✓ Graphe pour 'hello_435' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C5255E0>
# ✓ Graphe pour 'hello_436' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C527B60>
# ✓ Graphe pour 'hello_437' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C526BA0>
# ✓ Graphe pour 'hello_438' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4E60>
# ✓ Graphe pour 'hello_439' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4BC0>
# ✓ Graphe pour 'hello_440' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4E00>
# ✓ Graphe pour 'hello_441' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C646DB0>
# ✓ Graphe pour 'hello_442' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C647D70>
# ✓ Graphe pour 'hello_443' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C4F20>
# ✓ Graphe pour 'hello_444' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C675340>
# ✓ Graphe pour 'hello_445' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C7821E0>
# ✓ Graphe pour 'hello_446' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C73B0>
# ✓ Graphe pour 'hello_447' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C55E0>
# ✓ Graphe pour 'hello_448' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C6F00>
# ✓ Graphe pour 'hello_449' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C781D00>
# ✓ Graphe pour 'hello_450' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C7820C0>
# ✓ Graphe pour 'hello_451' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C780B90>
# ✓ Graphe pour 'hello_452' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C527E60>
# ✓ Graphe pour 'hello_453' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C526F30>
# ✓ Graphe pour 'hello_454' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C525070>
# ✓ Graphe pour 'hello_455' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C524410>
# ✓ Graphe pour 'hello_456' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C527620>
# ✓ Graphe pour 'hello_457' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C524B60>
# ✓ Graphe pour 'hello_458' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C525700>
# ✓ Graphe pour 'hello_459' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C783A10>
# ✓ Graphe pour 'hello_460' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C6778F0>
# ✓ Graphe pour 'hello_461' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C780E60>
# ✓ Graphe pour 'hello_462' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C781CA0>
# ✓ Graphe pour 'hello_463' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C783140>
# ✓ Graphe pour 'hello_464' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C783A40>
# ✓ Graphe pour 'hello_465' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C7890>
# ✓ Graphe pour 'hello_466' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C74D0>
# ✓ Graphe pour 'hello_467' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C7980>
# ✓ Graphe pour 'hello_468' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5DC0>
# ✓ Graphe pour 'hello_469' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C4C5670>
# ✓ Graphe pour 'hello_470' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C525580>
# ✓ Graphe pour 'hello_471' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C5271A0>
# ✓ Graphe pour 'hello_472' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C524FB0>
# ✓ Graphe pour 'hello_473' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C524200>
# ✓ Graphe pour 'hello_474' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C524C80>
# ✓ Graphe pour 'hello_475' créé avec 3 nœuds et 2 arêtes.
# <torch_geometric_temporal.signal.dynamic_graph_temporal_signal.DynamicGraphTemporalSignal object at 0x000001FA6C527A70>
# ✓ Graphe pour 'hello_476' créé avec 3 nœuds et 2 arêtes.

# %%
#########################UTILS############################################################################################################

def print_graph_info(graphs):
    for model_name, dataset in graphs.items():
        print(f"Modèle: {model_name}")
        print(f"  Nombre de nœuds: {dataset.features[0].shape[0]}")
        print(f"  Nombre d'arêtes: {dataset.edge_index.shape[1]}")
        print(f"  Dimensions des caractéristiques: {dataset.features[0].shape[1]}")
        print(f"  Dimensions des cibles: {dataset.targets[0].shape[1]}")
        print()

def print_features(graphs):
    for model_name, dataset in graphs.items():
        print(f"Modèle: {model_name}")
        for i, features in enumerate(dataset.features):
            print(f"  Snapshot {i+1}:")
            for j, feature in enumerate(features):
                target = dataset.targets[i][j]
                print(f"    Nœud {j}: features={feature}, target={target}")
        print()

def visualize_graph(G, model_name):
    import matplotlib.pyplot as plt

    pos = nx.spring_layout(G, seed=42)
    node_labels = {
        n: f"{n}\nfeatures={d['features']}\ntarget={d['target']}"
        for n, d in G.nodes(data=True)
    }

    edge_labels = {
        (u, v): f"{d['weight']}"
        for u, v, d in G.edges(data=True)
    }

    plt.figure(figsize=(8, 6))
    nx.draw(G, pos, with_labels=True, labels=node_labels, node_color='lightblue', node_size=1500, font_size=9)
    nx.draw_networkx_edge_labels(G, pos, edge_labels=edge_labels, font_color='red')
    plt.title(f"Graphe du modele '{model_name}' (edge weight = target source)")
    plt.show()


visualize_graph(G, 'hello_10')
print_features(graphs)
